# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
a = np.linspace(-20,20,2000)
b1 = np.tanh(a)
b2 =np.sin(a)
b3 =np.cos(a)
b4=np.tan(a)

# %% [markdown]
# # Plotting the Graphs with grid of 2 and 2 matrix

# %%
fig,axes = plt.subplots(nrows=2,ncols=2,figsize=(4,4))
axes[0][0].plot(a,b1)
axes[0][1].plot(a,b2)
axes[1][0].plot(a,b3)
axes[1][1].plot(a,b4)

# %%
axes[0][0].set_xlabel('Tan H')
axes[0][0].set_ylabel('Angle in radian')
# Out:
# Text(4.444444444444445, 0.5, 'Angle in radian')

# %%
axes[0][0].plot(a,b1)
axes[0][1].plot(a,b2)
axes[1][0].plot(a,b3)
axes[1][1].plot(a,b4)

# %%
fig,axes = plt.subplots(nrows=2,ncols=2,figsize=(4,4),dpi=100)
axes[0][0].plot(a,b1)
axes[0][1].plot(a,b2)
axes[1][0].plot(a,b3)
axes[1][1].plot(a,b4)
axes[0][0].set_xlabel('Tan H')
axes[0][0].set_ylabel('Angle in radian')
# Out:
# Text(0, 0.5, 'Angle in radian')

# %%
fig.subplots_adjust(hspace=1,wspace=2)

# %%
fig

# %%
fig.tight_layout()

# %%
fig

# %%
fig.suptitle("SubPlots ",fontsize=18,horizontalalignment="left")
fig

# %% [markdown]
# ## Plotting subplots in same graph , using legend to assign color to them

# %%
fig,axes =plt.subplots(dpi=100)

# %%
b1 = np.tanh(a)
b2 =np.sin(a)
b3 =np.cos(a)
b4=np.tan(a)
axes.plot(a,b1,label="tanh",color="#42e9f5",lw=0.5,ls="--")
axes.plot(a,b2,label="sin",color="#425af5",marker="v",ms="2.5")
axes.plot(a,b3,label="cos",color="#c242f5",lw=0.5,ls="--")
axes.legend()
plt.show()

# %%
fig

# %% [markdown]
# ## Ploting Datasets using Seaborn

# %%
import seaborn as sns

# %%
df =pd.read_csv("dm_office_sales.csv - dm_office_sales.csv.csv")

# %%
df
# Out:
#               division  level of education  training level  work experience  \
# 0             printers        some college               2                6
# 1             printers  associate's degree               2               10
# 2          peripherals         high school               0                9
# 3      office supplies  associate's degree               2                5
# 4      office supplies         high school               1                5
# ..                 ...                 ...             ...              ...
# 995  computer hardware  associate's degree               1                1
# 996  computer software  associate's degree               1                0
# 997        peripherals  associate's degree               2                8
# 998        peripherals  associate's degree               2                3
# 999  computer hardware        some college               0                9
#
#      salary   sales
# 0     91684  372302
# ...

# %%
plt.figure(figsize=(10,10),dpi=150)
sns.scatterplot(data=df,x='salary',y='sales',hue='level of education',style='level of education',palette='deep')
# Out:
# <Axes: xlabel='salary', ylabel='sales'>

# %%
plt.figure(figsize=(10,10),dpi=150)
sns.scatterplot(data=df,x='salary',y='sales',hue='level of education',style='level of education',palette='dark')
# Out:
# <Axes: xlabel='salary', ylabel='sales'>

# %%
df.head()
# Out:
#           division  level of education  training level  work experience  \
# 0         printers        some college               2                6
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802

# %%
plt.figure(figsize=(5,5),dpi=150)
sns.set_style('darkgrid')
sns.displot(x='salary',data=df,bins=20,color='green',edgecolor='red',kde=True)

# %%
plt.figure(figsize=(5,5),dpi=150)
sns.set_style('darkgrid')
sns.displot(x='salary',data=df,bins=20,color='green',edgecolor='red')

# %%
sns.kdeplot(x='salary',data=df)
# Out:
# <Axes: xlabel='salary', ylabel='Density'>

# %%
sns.histplot(x='salary',data=df,bins=20,color='purple',edgecolor='blue',kde=True)
# Out:
# <Axes: xlabel='salary', ylabel='Count'>

# %%
plt.figure(figsize=(2,2),dpi=150)
sns.boxplot(data=df,y='salary')
# Out:
# <Axes: ylabel='salary'>

# %%
plt.figure(figsize=(3,3),dpi=150)
sns.boxplot(data=df,y='salary',hue='training level')
# Out:
# <Axes: ylabel='salary'>

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='training level')

# %%
sns.boxplot(data=df,y='salary',x='work experience')
# Out:
# <Axes: xlabel='work experience', ylabel='salary'>
