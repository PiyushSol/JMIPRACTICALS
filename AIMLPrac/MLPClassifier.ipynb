# %% [markdown]
# ### MLP Classifier and GridSearch Tutorials

# %%
import numpy as np
import pandas as pd

# %%
#Reading Dataset
df =pd.read_csv("wine.csv - wine.csv.csv")
df.head()
# Out:
#    Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0     1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1     1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2     1    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3     1    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4     1    13.24        2.59  2.87  21.0  118     2.80        2.69
#
#    Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                  0.28     2.29       5.64  1.04  3.92     1065
# 1                  0.26     1.28       4.38  1.05  3.40     1050
# 2                  0.30     2.81       5.68  1.03  3.17     1185
# 3                  0.24     2.18       7.80  0.86  3.45     1480
# 4                  0.39     1.82       4.32  1.04  2.93      735

# %%
X=df.iloc[:,1:]
y=df.iloc[:,0]

# %%
X.shape
# Out:
# (178, 13)

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 173    3
# 174    3
# 175    3
# 176    3
# 177    3
# Name: Wine, Length: 178, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_Train , X_Test , y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=408,stratify=y)

# %%
#Defining Pipeline for the model
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
pipe = Pipeline(
   steps= [
        ('scaler',StandardScaler()),
        ('mlp',MLPClassifier(max_iter=1500,random_state=408))
    ]
)

# %%
#Defining HyperParameter Grid
#Here the mlp used is the one which was defined above in the above pipeline
param_grid = {
    'mlp__hidden_layer_sizes':[(10,),(10,10),(5,10),(5,)],
    'mlp__activation':['relu','tanh'],
    'mlp__solver':['adam','sgd'],
    'mlp__learning_rate':['constant','adaptive'],
    'mlp__alpha':[0.0001,0.001],
}

# %%
##Defining Grid Search with CV
from sklearn.model_selection import GridSearchCV
grid_search=GridSearchCV(
    pipe,param_grid=param_grid,cv=10,scoring='accuracy',verbose=1
)

# %%
grid_search.fit(X_Train,y_train)
# Out:
# Fitting 10 folds for each of 64 candidates, totalling 640 fits

# %%
##Now applying estimators
estimators = grid_search.cv_results_['params']
estimators_df = pd.DataFrame(estimators)
estimators_df
# Out:
#    mlp__activation  mlp__alpha mlp__hidden_layer_sizes mlp__learning_rate  \
# 0             relu      0.0001                   (10,)           constant
# 1             relu      0.0001                   (10,)           constant
# 2             relu      0.0001                   (10,)           adaptive
# 3             relu      0.0001                   (10,)           adaptive
# 4             relu      0.0001                (10, 10)           constant
# ..             ...         ...                     ...                ...
# 59            tanh      0.0010                 (5, 10)           adaptive
# 60            tanh      0.0010                    (5,)           constant
# 61            tanh      0.0010                    (5,)           constant
# 62            tanh      0.0010                    (5,)           adaptive
# 63            tanh      0.0010                    (5,)           adaptive
#
#    mlp__solver
# 0         adam
# 1          sgd
# 2         adam
# 3          sgd
# 4         adam
# ..         ...
# 59         sgd
# 60        adam
# 61         sgd
# 62        adam
# 63         sgd
#
# [64 rows x 5 columns]

# %%
all_estimators = grid_search.cv_results_
all_estimators= pd.DataFrame(all_estimators)
all_estimators
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.239166      0.056004         0.002404        0.001653
# 1        0.281453      0.011683         0.001792        0.000742
# 2        0.203258      0.004142         0.001594        0.000489
# 3        0.294014      0.009271         0.001692        0.000455
# 4        0.189791      0.015723         0.002101        0.000546
# ..            ...           ...              ...             ...
# 59       0.336517      0.005267         0.001692        0.000455
# 60       0.306580      0.020514         0.001907        0.000706
# 61       0.304894      0.034628         0.002995        0.003337
# 62       0.296734      0.011982         0.001895        0.000299
# 63       0.344698      0.065590         0.002091        0.001369
#
#    param_mlp__activation  param_mlp__alpha param_mlp__hidden_layer_sizes  \
# 0                   relu            0.0001                         (10,)
# 1                   relu            0.0001                         (10,)
# 2                   relu            0.0001                         (10,)
# 3                   relu            0.0001                         (10,)
# 4                   relu            0.0001                      (10, 10)
# ..                   ...               ...                           ...
# 59                  tanh            0.0010                       (5, 10)
# 60                  tanh            0.0010                          (5,)
# 61                  tanh            0.0010                          (5,)
# 62                  tanh            0.0010                          (5,)
# 63                  tanh            0.0010                          (5,)
#
#    param_mlp__learning_rate param_mlp__solver  \
# 0                  constant              adam
# 1                  constant               sgd
# 2                  adaptive              adam
# 3                  adaptive               sgd
# 4                  constant              adam
# ..                      ...               ...
# 59                 adaptive               sgd
# 60                 constant              adam
# 61                 constant               sgd
# 62                 adaptive              adam
# 63                 adaptive               sgd
#
#                                                params  ...  split3_test_score  \
# 0   {'mlp__activation': 'relu', 'mlp__alpha': 0.00...  ...           0.928571
# 1   {'mlp__activation': 'relu', 'mlp__alpha': 0.00...  ...           1.000000
# 2   {'mlp__activation': 'relu', 'mlp__alpha': 0.00...  ...           0.928571
# 3   {'mlp__activation': 'relu', 'mlp__alpha': 0.00...  ...           1.000000
# 4   {'mlp__activation': 'relu', 'mlp__alpha': 0.00...  ...           0.928571
# ..                                                ...  ...                ...
# 59  {'mlp__activation': 'tanh', 'mlp__alpha': 0.00...  ...           0.857143
# 60  {'mlp__activation': 'tanh', 'mlp__alpha': 0.00...  ...           0.928571
# 61  {'mlp__activation': 'tanh', 'mlp__alpha': 0.00...  ...           0.928571
# 62  {'mlp__activation': 'tanh', 'mlp__alpha': 0.00...  ...           0.928571
# 63  {'mlp__activation': 'tanh', 'mlp__alpha': 0.00...  ...           0.928571
#
#     split4_test_score  split5_test_score  split6_test_score  \
# 0                 1.0           1.000000           0.928571
# 1                 1.0           0.928571           0.928571
# 2                 1.0           1.000000           0.928571
# 3                 1.0           0.928571           0.928571
# 4                 1.0           1.000000           1.000000
# ..                ...                ...                ...
# 59                1.0           1.000000           1.000000
# 60                1.0           1.000000           1.000000
# 61                1.0           1.000000           1.000000
# 62                1.0           1.000000           1.000000
# 63                1.0           1.000000           1.000000
#
#     split7_test_score  split8_test_score  split9_test_score  mean_test_score  \
# 0                 1.0           0.857143           0.928571         0.964286
# 1                 1.0           0.857143           0.928571         0.964286
# 2                 1.0           0.857143           0.928571         0.964286
# 3                 1.0           0.857143           0.928571         0.964286
# 4                 1.0           0.857143           0.857143         0.964286
# ..                ...                ...                ...              ...
# 59                1.0           1.000000           0.928571         0.978571
# 60                1.0           0.857143           0.857143         0.957143
# 61                1.0           0.928571           1.000000         0.985714
# 62                1.0           0.857143           0.857143         0.957143
# 63                1.0           0.928571           1.000000         0.985714
#
#     std_test_score  rank_test_score
# 0         0.047916               33
# 1         0.047916               33
# 2         0.047916               33
# 3         0.047916               33
# 4         0.057588               33
# ..             ...              ...
# 59        0.045737               21
# 60        0.057143               57
# 61        0.028571                1
# 62        0.057143               57
# 63        0.028571                1
#
# [64 rows x 23 columns]

# %%
##Obtaining Best Model
best_model = grid_search.best_estimator_
best_model
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('mlp',
#                  MLPClassifier(hidden_layer_sizes=(5,), max_iter=1500,
#                                random_state=408, solver='sgd'))])

# %%
y_predict = best_model.predict(X_Test)

# %%
y_predict
# Out:
# array([3, 3, 2, 1, 2, 3, 2, 1, 1, 2, 2, 3, 2, 1, 2, 3, 3, 3, 1, 1, 2, 3,
#        2, 3, 2, 2, 2, 2, 1, 1, 1, 2, 1, 3, 1, 1])

# %%
grid_search.best_params_
# Out:
# {'mlp__activation': 'relu',
#  'mlp__alpha': 0.0001,
#  'mlp__hidden_layer_sizes': (5,),
#  'mlp__learning_rate': 'constant',
#  'mlp__solver': 'sgd'}
